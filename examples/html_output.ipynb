# %% [markdown]
# # HTML-результат
#
# Этот пример содержит HTML в результате выполнения кодовой ячейки.

# %%
html = "<strong>Готово</strong>"
html
# Out:
# <div>
#     <h2>Пример HTML</h2>
#     <p>SHOULD_NOT_APPEAR_HTML_OUTPUT</p>
# </div>
