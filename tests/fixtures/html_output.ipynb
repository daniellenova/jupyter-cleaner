# %%
from IPython.display import HTML, display

# %%
display(HTML('<section><h2>Report</h2><p>This is ordinary HTML, not a table.</p></section>'))
# Out:
# <section><h2>Report</h2><p>This is ordinary HTML, not a table.</p></section>
